# %%
x = int(input('x 좌표를 입력하세요 : ',))
y = int(input('y 좌표를 입력하세요 : ',))

if x > 0 and y > 0:
    print('Quadrant 1')
elif x > 0 and y < 0:
    print('Quadrant 2')
elif x < 0 and y < 0:
    print('Quadrant 3')
elif x < 0 and y > 0:
    print('Quadrant 4')
else:
    print('원점입니다.')
# Out:
# x 좌표를 입력하세요 : 0
# y 좌표를 입력하세요 : 0
# 원점입니다.

# %%
def selfnumber(start,end):
    lis=[]
    for i in range(start,end+1):
        lis.append(i//10+i%10+i)

    return set(list(range(start,end+1))) - set(lis)


self_list = list(selfnumber(1,10000))
self_list.sort
print(self_list)
# Out:
# [1, 8193, 3, 6147, 5, 4101, 7, 2055, 9, 8204, 6158, 4112, 2066, 20, 8215, 6169, 4123, 2077, 31, 8226, 6180, 4134, 2088, 42, 8237, 6191, 4145, 2099, 53, 8248, 6202, 4156, 2110, 64, 8259, 6213, 4167, 2121, 75, 8270, 6224, 4178, 2132, 86, 8281, 6235, 4189, 2143, 97, 8292, 6246, 4200, 2154, 108, 8303, 6257, 4211, 2165, 119, 8314, 6268, 4222, 2176, 130, 8325, 6279, 4233, 2187, 141, 8336, 6290, 4244, 2198, 152, 8347, 6301, 4255, 2209, 163, 8358, 6312, 4266, 2220, 174, 8369, 6323, 4277, 2231, 185, 8380, 6334, 4288, 2242, 196, 8391, 6345, 4299, 2253, 207, 8402, 6356, 4310, 2264, 218, 8413, 6367, 4321, 2275, 229, 8424, 6378, 4332, 2286, 240, 8435, 6389, 4343, 2297, 251, 8446, 6400, 4354, 2308, 262, 8457, 6411, 4365, 2319, 273, 8468, 6422, 4376, 2330, 284, 8479, 6433, 4387, 2341, 295, 8490, 6444, 4398, 2352, 306, 8501, 6455, 4409, 2363, 317, 8512, 6466, 4420, 2374, 328, 8523, 6477, 4431, 2385, 339, 8534, 6488, 4442, 2396, 350, 8545, 6499, 4453, 2407, 361, 8556, 6510, 4464, 2418, 372, 8567, 652
# ...

# %%
def selfnumber(start,end):
    lis=[]
    selflis=[]
    for i in range(start,end+1):
        print(i)
        type(i)
        j = str(i)
        print(j)
        type(j)
        k = ",".join(j)
        l = list(k.split(","))
        m = sum(l)

        lis.append(m)
        
    for i in range(start, end+1):
        if i in lis:
            continue
        else:
            print(i)
selfnumber(1,10000)
# Out:
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-85eec61e9bae> in <module>
#      19         else:
#      20             print(i)
# ---> 21 selfnumber(1,10000)
#
# <ipython-input-47-85eec61e9bae> in selfnumber(start, end)
#      10         k = ",".join(j)
#      11         l = list(k.split(","))
# ---> 12         m = sum(l)
#      13
#      14         lis.append(m)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-27ff2061ce7f> in <module>
#       7     k = ",".join(j)
#       8     l = list(k.split(","))
# ----> 9     m = sum(l)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
